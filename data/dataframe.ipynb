# %%
import pandas as pd

# %%
df = pd.read_csv('OnlineQN_in_CarRacing-v2.csv')
df["reward"].sum()
# Out:
# -32

# %%
df.head(60)
# Out:
#     Unnamed: 0  episode  round  \
# 0            0        0      0
# 1            1        0      1
# 2            2        0      2
# 3            3        0      3
# 4            4        0      4
# 5            5        0      5
# 6            6        0      6
# 7            7        0      7
# 8            8        0      8
# 9            9        0      9
# 10          10        0     10
# 11          11        0     11
# 12          12        0     12
# 13          13        0     13
# 14          14        0     14
# 15          15        0     15
# 16          16        0     16
# 17          17        0     17
# 18          18        0     18
# 19          19        0     19
# 20          20        0     20
# 21          21        0     21
# 22          22        0     22
# 23          23        0     23
# 24          24        0     24
# 25          25        0     25
# 26          26        0     26
# 27          27        0     27
# 28          28        0     28
# ...
