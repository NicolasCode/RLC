# %%
import gymnasium as gym
import numpy as np
from IPython.display import clear_output, display
import matplotlib.pyplot as plt

# %%
env = gym.make('MountainCar-v0', render_mode='rgb_array')
env.reset()
img = env.render()
clear_output(wait=True)
display(plt.imshow(img))

# %%
for _ in range(10):
    action = env.action_space.sample()
    result = env.step(action)
    print(result)
# Out:
# (array([-0.45938486,  0.00052524], dtype=float32), -1.0, False, False, {})
# (array([-4.5933825e-01,  4.6604746e-05], dtype=float32), -1.0, False, False, {})
# (array([-4.5977062e-01, -4.3236944e-04], dtype=float32), -1.0, False, False, {})
# (array([-4.5967877e-01,  9.1839465e-05], dtype=float32), -1.0, False, False, {})
# (array([-4.600634e-01, -3.846278e-04], dtype=float32), -1.0, False, False, {})
# (array([-4.5992166e-01,  1.4173707e-04], dtype=float32), -1.0, False, False, {})
# (array([-0.46125463, -0.00133294], dtype=float32), -1.0, False, False, {})
# (array([-0.4620524, -0.0007978], dtype=float32), -1.0, False, False, {})
# (array([-0.4633092 , -0.00125678], dtype=float32), -1.0, False, False, {})
# (array([-0.4660157 , -0.00270649], dtype=float32), -1.0, False, False, {})

# %%
state = (result[0][0], result[0][1])
state
# Out:
# (-0.4660157, -0.0027064916)

# %%
weights = np.random.sample(3)
weights
# Out:
# array([0.75953288, 0.99871406, 0.89870482])

# %%
action_prediction = np.dot(weights, state_action_pair)
prediction
# Out:
# array([[-0.12082284, -0.00486244,  0.        ],
#        [-0.12082284, -0.00486244,  0.82098379],
#        [-0.12082284, -0.00486244,  1.64196758]])
