# %% [markdown]
# # Q_learning on PitLaberynth

# %% [markdown]
# # Static

# %%
from utils.performer import Performer
from utils.interpreters import gridW_nS_interpreter

# %%
agent_parameters = {'nA':4,
                    'nS':4**8,
                    'gamma':1,
                    'epsilon':0.1,
                    'alpha':0.1
                   }
env_parameters = {'size':4, 
                  'mode':'static'
                 }
perf = Performer(env_name='PitLaberynth',
                 env_parameters=env_parameters,
                 state_interpreter=gridW_nS_interpreter,
                 agent_name='Q_learning',
                 agent_parameters=agent_parameters)

# %%
perf.run(from_file=False, to_video=True)
# Out:
# Moviepy - Building video /Notebooks/clase-rl/Talleres_codigo/Taller2/videos/Q_learning_in_PitLaberynth/rl-video-episode-0.mp4.
# Moviepy - Writing video /Notebooks/clase-rl/Talleres_codigo/Taller2/videos/Q_learning_in_PitLaberynth/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /Notebooks/clase-rl/Talleres_codigo/Taller2/videos/Q_learning_in_PitLaberynth/rl-video-episode-0.mp4
# Number of rounds: 12
# Total reward: -21.0

# %%
perf.train(num_episodes=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Data saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/data/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.csv
# Agent saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/models/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.json
# Plot saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/images/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.png

# %%
perf.test(num_episodes=100)
# Out:
# Loading agent from /Notebooks/clase-rl/Talleres_codigo/Taller2/models/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.json
#   0%|          | 0/100 [00:00<?, ?it/s]
# Average sum of rewards:
#  model
# Q_learning    4.0
# Name: reward, dtype: float64
#
# Episode termination percentage:
#  model
# Q_learning    100.0
# Name: done, dtype: float64
# Plot saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/images/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth_test.png

# %%
perf.run(from_file=True, no_exploration=True, to_video=True)
# Out:
# Moviepy - Building video /Notebooks/clase-rl/Talleres_codigo/Taller2/videos/Q_learning_in_PitLaberynth/rl-video-episode-0.mp4.
# Moviepy - Writing video /Notebooks/clase-rl/Talleres_codigo/Taller2/videos/Q_learning_in_PitLaberynth/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /Notebooks/clase-rl/Talleres_codigo/Taller2/videos/Q_learning_in_PitLaberynth/rl-video-episode-0.mp4
# Number of rounds: 7
# Total reward: 4.0

# %% [markdown]
# # Player

# %%
env_parameters = {'size':4, 
                  'mode':'player'
                 }
perf = Performer(env_name='PitLaberynth',
                 env_parameters=env_parameters,
                 state_interpreter=gridW_nS_interpreter,
                 agent_name='Q_learning',
                 agent_parameters=agent_parameters)

# %%
perf.train(num_episodes=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Data saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/data/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.csv
# Agent saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/models/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.json
# Plot saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/images/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.png

# %%
perf.test(num_episodes=100)
# Out:
# Loading agent from /Notebooks/clase-rl/Talleres_codigo/Taller2/models/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.json
#   0%|          | 0/100 [00:00<?, ?it/s]
# Average sum of rewards:
#  model
# Q_learning    6.23
# Name: reward, dtype: float64
#
# Episode termination percentage:
#  model
# Q_learning    100.0
# Name: done, dtype: float64
# Plot saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/images/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth_test.png

# %% [markdown]
# # Random

# %%
env_parameters = {'size':4, 
                  'mode':'random'
                 }
perf = Performer(env_name='PitLaberynth',
                 env_parameters=env_parameters,
                 state_interpreter=gridW_nS_interpreter,
                 agent_name='Q_learning',
                 agent_parameters=agent_parameters)

# %%
perf.train(num_episodes=100)

# %%
perf.test(num_episodes=100)

# %%
perf.train(num_episodes=100000)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Data saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/data/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.csv
# Agent saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/models/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.json
# Plot saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/images/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.png

# %%
perf.test(num_episodes=100)
# Out:
# Loading agent from /Notebooks/clase-rl/Talleres_codigo/Taller2/models/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth.json
#   0%|          | 0/100 [00:00<?, ?it/s]
# Average sum of rewards:
#  model
# Q_learning   -47.73
# Name: reward, dtype: float64
#
# Episode termination percentage:
#  model
# Q_learning    73.0
# Name: done, dtype: float64
# Plot saved to /Notebooks/clase-rl/Talleres_codigo/Taller2/images/Q_learning_in_PitLaberynth/Q_learning_in_PitLaberynth_test.png
